# %%
import pandas as pd
pd.set_option('display.max_columns', 64)
pd.set_option('display.max_rows', 64)
arquivos = pd.read_csv(r'/Users/gustavohenriquebonatopiresdemoraes/ia-portfolio-gustavo/exercicios/modulo1/Data_train_reduced.csv')
arquivos
# Out:
#       Respondent.ID  Product.ID      Product  Instant.Liking  \
# 0              3800         121  Deodorant B               1
# 1              3801         121  Deodorant B               0
# 2              3802         121  Deodorant B               0
# 3              3803         121  Deodorant B               1
# 4              3804         121  Deodorant B               1
# ...             ...         ...          ...             ...
# 2495           5695         230  Deodorant J               0
# 2496           5696         230  Deodorant J               0
# 2497           5697         230  Deodorant J               1
# 2498           5698         230  Deodorant J               0
# 2499           5699         230  Deodorant J               0
#
#       q1_1.personal.opinion.of.this.Deodorant  q2_all.words  \
# 0                                           4             1
# 1                                           5             1
# ...

# %%
arquivos.head()
# Out:
#    Respondent.ID  Product.ID      Product  Instant.Liking  \
# 0           3800         121  Deodorant B               1
# 1           3801         121  Deodorant B               0
# 2           3802         121  Deodorant B               0
# 3           3803         121  Deodorant B               1
# 4           3804         121  Deodorant B               1
#
#    q1_1.personal.opinion.of.this.Deodorant  q2_all.words  \
# 0                                        4             1
# 1                                        5             1
# 2                                        6             1
# 3                                        4             0
# 4                                        4             1
#
#    q3_1.strength.of.the.Deodorant  q4_1.artificial.chemical  q4_2.attractive  \
# 0                               4                         2                5
# 1                               4                         4                2
# ...

# %%
arquivos.shape
# Out:
# (2500, 64)

# %%
arquivos.dtypes
# Out:
# Respondent.ID                                                int64
# Product.ID                                                   int64
# Product                                                     object
# Instant.Liking                                               int64
# q1_1.personal.opinion.of.this.Deodorant                      int64
# q2_all.words                                                 int64
# q3_1.strength.of.the.Deodorant                               int64
# q4_1.artificial.chemical                                     int64
# q4_2.attractive                                              int64
# q4_3.bold                                                    int64
# q4_4.boring                                                  int64
# q4_5.casual                                                  int64
# q4_6.cheap                                                   int64
# q4_7.clean                                                   int64
# ...

# %%
faltantes = arquivos.isnull().sum()
faltantes_percentual = (arquivos.isnull().sum() / len(arquivos['Product'])) * 100
faltantes_percentual
# Out:
# Respondent.ID                                               0.0
# Product.ID                                                  0.0
# Product                                                     0.0
# Instant.Liking                                              0.0
# q1_1.personal.opinion.of.this.Deodorant                     0.0
# q2_all.words                                                0.0
# q3_1.strength.of.the.Deodorant                              0.0
# q4_1.artificial.chemical                                    0.0
# q4_2.attractive                                             0.0
# q4_3.bold                                                   0.0
# q4_4.boring                                                 0.0
# q4_5.casual                                                 0.0
# q4_6.cheap                                                  0.0
# q4_7.clean                                                  0.0
# q4_8.easy.to.wear                                           0.0
# ...

# %%
#arquivos_limpo = arquivos.dropna(axis=1, thresh=len(arquivos)*0.9)

# %%
#colunas_removidas = list(set(arquivos.columns) - set(arquivos_limpo.columns))
#print("Colunas removidas:", colunas_removidas)

# %%
arquivos.drop('q8.20', axis=1, inplace=True)
arquivos.drop('q8.18', axis=1, inplace=True)
arquivos.drop('q8.17', axis=1, inplace=True)
arquivos.drop('q8.8', axis=1, inplace=True)
arquivos.drop('q8.9', axis=1, inplace=True)
arquivos.drop('q8.10', axis=1, inplace=True)
arquivos.drop('q8.2', axis=1, inplace=True)
arquivos.drop('Respondent.ID', axis=1, inplace=True)
arquivos.drop('Product', axis=1, inplace=True)
arquivos.drop('q1_1.personal.opinion.of.this.Deodorant', axis=1, inplace=True)

#arquivos.drop('Respondent.ID', axis=1, inplace=True)
#arquivos.drop('Product', axis=1, inplace=True)
#arquivos.drop('q1_1.personal.opinion.of.this.Deodorant', axis=1, inplace=True)

# %%
arquivos['q8.12'].fillna(arquivos['q8.12'].median(), inplace=True)
arquivos['q8.7'].fillna(arquivos['q8.12'].median(), inplace=True)
# Out:
# /var/folders/yt/y3y975dn4895dqr8zg7d0rhc0000gn/T/ipykernel_19885/290526835.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   arquivos['q8.12'].fillna(arquivos['q8.12'].median(), inplace=True)
# /var/folders/yt/y3y975dn4895dqr8zg7d0rhc0000gn/T/ipykernel_19885/290526835.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
faltantes = arquivos.isnull().sum()
faltantes_percentual = (arquivos.isnull().sum() / len(arquivos['Product.ID'])) * 100
faltantes_percentual
# Out:
# Product.ID                                                 0.0
# Instant.Liking                                             0.0
# q2_all.words                                               0.0
# q3_1.strength.of.the.Deodorant                             0.0
# q4_1.artificial.chemical                                   0.0
# q4_2.attractive                                            0.0
# q4_3.bold                                                  0.0
# q4_4.boring                                                0.0
# q4_5.casual                                                0.0
# q4_6.cheap                                                 0.0
# q4_7.clean                                                 0.0
# q4_8.easy.to.wear                                          0.0
# q4_9.elegant                                               0.0
# q4_10.feminine                                             0.0
# q4_11.for.someone.like.me                                  0.0
# ...

# %%
#Separando as variáveis entre preditoras e variável target
y = arquivos['Instant.Liking']
x = arquivos.drop('Instant.Liking', axis = 1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

#Separando os dados em folds:
kfold = StratifiedKFold(n_splits=5)

#Criando o modelo:
modelo = LogisticRegression()
resultado = cross_val_score(modelo,x,y, cv = kfold)

#Imprimindo a acurácia: print (resultado.mean( ))
print(resultado.mean())
# Out:
# 0.7524
# /opt/anaconda3/envs/segmentador/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/envs/segmentador/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
# ...
