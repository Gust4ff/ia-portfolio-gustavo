# %%
import pandas as pd 
arquivos = pd.read_csv(r'/Users/gustavohenriquebonatopiresdemoraes/ia-portfolio-gustavo/exercicios/modulo1/wine_dataset.csv')
arquivos.head(1990)
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1985            5.0              0.17         0.56             1.5      0.026
# 1986            6.3              0.39         0.35             5.9      0.040
# 1987            6.7              0.21         0.32             5.4      0.047
# 1988            7.0              0.30         0.38            14.9      0.032
# 1989            7.0              0.30         0.38            14.9      0.032
#
# ...

# %%
arquivos.shape
# Out:
# (6497, 13)

# %%
Y = arquivos['style']
X = arquivos.drop('style', axis = 1)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.naive_bayes import GaussianNB

modelo = GaussianNB()
skfold = StratifiedKFold(n_splits = 3)
resultado = cross_val_score(modelo, X, Y, cv = skfold)

resultado
print('Acúracia', resultado.mean())
# Out:
# Acúracia 0.9693707141724901
